# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    database="postgres",
    user="postgres",
    password="1234",
    port="5432"
)

cur = conn.cursor()

print("Connected successfully")
# Out:
# Connected successfully

# %%
cur.execute("""
CREATE TABLE IF NOT EXISTS books (
    id SERIAL PRIMARY KEY,
    title VARCHAR(100),
    author VARCHAR(100),
    available BOOLEAN
);
""")

conn.commit()

# %%
cur.execute("""
INSERT INTO books (title, author, available)
VALUES ('Python Basics', 'Piyush', TRUE);
""")

conn.commit()

# %%
cur.execute("SELECT * FROM books")
rows = cur.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Python Basics', 'Piyush', True)
